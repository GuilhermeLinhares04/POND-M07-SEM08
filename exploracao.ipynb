# %%
import pandas as pd

# %%
# Convertendo dados para csv
df = pd.read_excel('dados/Bitcoin_07_09_2023-06_09_2024_historical_data_coinmarketcap.xlsx')
df.to_csv('dados/Bitcoin_1Y.csv', index=False)
df
# Out:
#                      timeOpen                 timeClose  \
# 0    2024-09-05T00:00:00.000Z  2024-09-05T23:59:59.999Z
# 1    2024-09-04T00:00:00.000Z  2024-09-04T23:59:59.999Z
# 2    2024-09-03T00:00:00.000Z  2024-09-03T23:59:59.999Z
# 3    2024-09-02T00:00:00.000Z  2024-09-02T23:59:59.999Z
# 4    2024-09-01T00:00:00.000Z  2024-09-01T23:59:59.999Z
# ..                        ...                       ...
# 359  2023-09-12T00:00:00.000Z  2023-09-12T23:59:59.999Z
# 360  2023-09-11T00:00:00.000Z  2023-09-11T23:59:59.999Z
# 361  2023-09-10T00:00:00.000Z  2023-09-10T23:59:59.999Z
# 362  2023-09-09T00:00:00.000Z  2023-09-09T23:59:59.999Z
# 363  2023-09-08T00:00:00.000Z  2023-09-08T23:59:59.999Z
#
#                      timeHigh                   timeLow  name  \
# 0    2024-09-05T00:30:00.000Z  2024-09-05T21:36:00.000Z  2781
# 1    2024-09-04T16:39:00.000Z  2024-09-04T01:06:00.000Z  2781
# 2    2024-09-03T02:16:00.000Z  2024-09-03T23:59:00.000Z  2781
# ...

# %%
# Verificando o tipo de dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timeOpen   364 non-null    object
#  1   timeClose  364 non-null    object
#  2   timeHigh   364 non-null    object
#  3   timeLow    364 non-null    object
#  4   name       364 non-null    int64
#  5   open       364 non-null    int64
#  6   high       364 non-null    int64
#  7   low        364 non-null    int64
#  8   close      364 non-null    int64
#  9   volume     364 non-null    float64
#  10  marketCap  364 non-null    float64
#  11  timestamp  364 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 34.3+ KB

# %%
# Normalizando valores inteiros para os preços
for col in df.select_dtypes(include=['int64']).columns:
    df[col] = df[col] // 10**10  # Dividindo por 10^10 e descartando os últimos 10 dígitos

df
# Out:
#                      timeOpen                 timeClose  \
# 0    2024-09-05T00:00:00.000Z  2024-09-05T23:59:59.999Z
# 1    2024-09-04T00:00:00.000Z  2024-09-04T23:59:59.999Z
# 2    2024-09-03T00:00:00.000Z  2024-09-03T23:59:59.999Z
# 3    2024-09-02T00:00:00.000Z  2024-09-02T23:59:59.999Z
# 4    2024-09-01T00:00:00.000Z  2024-09-01T23:59:59.999Z
# ..                        ...                       ...
# 359  2023-09-12T00:00:00.000Z  2023-09-12T23:59:59.999Z
# 360  2023-09-11T00:00:00.000Z  2023-09-11T23:59:59.999Z
# 361  2023-09-10T00:00:00.000Z  2023-09-10T23:59:59.999Z
# 362  2023-09-09T00:00:00.000Z  2023-09-09T23:59:59.999Z
# 363  2023-09-08T00:00:00.000Z  2023-09-08T23:59:59.999Z
#
#                      timeHigh                   timeLow  name   open   high  \
# 0    2024-09-05T00:30:00.000Z  2024-09-05T21:36:00.000Z     0  57971  58300
# 1    2024-09-04T16:39:00.000Z  2024-09-04T01:06:00.000Z     0  57430  58511
# ...

# %%
# Verificar número de dados da coluna 'open'
df['open'].value_counts()
# Out:
# open
# 60793    2
# 67911    2
# 43728    2
# 69392    2
# 43948    1
#         ..
# 63162    1
# 62332    1
# 61191    1
# 63055    1
# 26245    1
# Name: count, Length: 360, dtype: int64

# %%
# Função para multiplicar por 10 os valores menores que 10 mil
for col in df.select_dtypes(include=['int64']).columns:
    df[col] = df[col].apply(lambda x: x * 10 if x < 10000 else x)


df.to_csv('dados/Bitcoin_1Y_Normalizado.csv', index=False)
df
# Out:
#                      timeOpen                 timeClose  \
# 0    2024-09-05T00:00:00.000Z  2024-09-05T23:59:59.999Z
# 1    2024-09-04T00:00:00.000Z  2024-09-04T23:59:59.999Z
# 2    2024-09-03T00:00:00.000Z  2024-09-03T23:59:59.999Z
# 3    2024-09-02T00:00:00.000Z  2024-09-02T23:59:59.999Z
# 4    2024-09-01T00:00:00.000Z  2024-09-01T23:59:59.999Z
# ..                        ...                       ...
# 359  2023-09-12T00:00:00.000Z  2023-09-12T23:59:59.999Z
# 360  2023-09-11T00:00:00.000Z  2023-09-11T23:59:59.999Z
# 361  2023-09-10T00:00:00.000Z  2023-09-10T23:59:59.999Z
# 362  2023-09-09T00:00:00.000Z  2023-09-09T23:59:59.999Z
# 363  2023-09-08T00:00:00.000Z  2023-09-08T23:59:59.999Z
#
#                      timeHigh                   timeLow  name   open   high  \
# 0    2024-09-05T00:30:00.000Z  2024-09-05T21:36:00.000Z     0  57971  58300
# 1    2024-09-04T16:39:00.000Z  2024-09-04T01:06:00.000Z     0  57430  58511
# ...

# %%
# Convertendo a coluna 'date' para datetime
df['timeOpen'] = pd.to_datetime(df['timeOpen'])
df['timeClose'] = pd.to_datetime(df['timeClose'])
df['timeHigh'] = pd.to_datetime(df['timeHigh'])
df['timeLow'] = pd.to_datetime(df['timeLow'])
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Ordem cronológica pela coluna 'timestamp'
df = df.sort_values(by='timestamp')

df
# Out:
#                      timeOpen                        timeClose  \
# 363 2023-09-08 00:00:00+00:00 2023-09-08 23:59:59.999000+00:00
# 362 2023-09-09 00:00:00+00:00 2023-09-09 23:59:59.999000+00:00
# 361 2023-09-10 00:00:00+00:00 2023-09-10 23:59:59.999000+00:00
# 360 2023-09-11 00:00:00+00:00 2023-09-11 23:59:59.999000+00:00
# 359 2023-09-12 00:00:00+00:00 2023-09-12 23:59:59.999000+00:00
# ..                        ...                              ...
# 4   2024-09-01 00:00:00+00:00 2024-09-01 23:59:59.999000+00:00
# 3   2024-09-02 00:00:00+00:00 2024-09-02 23:59:59.999000+00:00
# 2   2024-09-03 00:00:00+00:00 2024-09-03 23:59:59.999000+00:00
# 1   2024-09-04 00:00:00+00:00 2024-09-04 23:59:59.999000+00:00
# 0   2024-09-05 00:00:00+00:00 2024-09-05 23:59:59.999000+00:00
#
#                      timeHigh                   timeLow  name   open   high  \
# 363 2023-09-08 00:58:00+00:00 2023-09-08 10:07:00+00:00     0  26245  26410
# ...
